# %% [markdown]
# # Data importing and preprocessing

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('DataSet/Movie_collection_train.csv',header=0)
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000           20.1264               59.62               0.462
# 1       43200           20.5462               69.14               0.531
# 2       69400           20.5458               69.14               0.531
# 3       66800           20.6474               59.36               0.542
# 4       72400           21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
df.shape
# Out:
# (400, 19)

# %%
df.describe()
# Out:
#           Collection  Marketin_expense  Production_expense  \
# count     400.000000        400.000000          400.000000
# mean    48646.500000         55.017180           73.832700
# std     18308.499136        119.755634           13.023426
# min     10000.000000         20.126400           55.920000
# 25%     37800.000000         21.321950           63.250000
# 50%     45000.000000         23.214700           69.030000
# 75%     56500.000000         34.638300           82.840000
# max    100000.000000       1799.524000          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          400.000000    400.000000    400.000000          400.000000
# mean             0.469881  35197.771537    137.581750            7.810275
# std              0.113920   4075.766926     28.990673            1.088694
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %%
sns.jointplot(x='Marketin_expense',y='Collection',data=df)

# %%
sns.jointplot(x='Twitter_hastags',y='Collection',data=df)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000           20.1264               59.62               0.462
# 1       43200           20.5462               69.14               0.531
# 2       69400           20.5458               69.14               0.531
# 3       66800           20.6474               59.36               0.542
# 4       72400           21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
sns.countplot(x='3D_available',data=df)
# Out:
# <AxesSubplot:xlabel='3D_available', ylabel='count'>

# %%
sns.countplot(x='MPAA_film_rating',data=df)
# Out:
# <AxesSubplot:xlabel='MPAA_film_rating', ylabel='count'>

# %%
sns.countplot(x='Genre',data=df)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %% [markdown]
# 1. Missing values in Time_taken
# 2. Skewness or outliers in Marketin_expense,Production_expense
# 3. Outliers in  Twitter_hastags
# 4. MPAA_film_rating has only 'YES' values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           400 non-null    int64
#  1   Marketin_expense     400 non-null    float64
#  2   Production_expense   400 non-null    float64
#  3   Multiplex_coverage   400 non-null    float64
#  4   Budget               400 non-null    float64
#  5   Movie_length         400 non-null    float64
#  6   Lead_ Actor_Rating   400 non-null    float64
#  7   Lead_Actress_rating  400 non-null    float64
#  8   Director_rating      400 non-null    float64
#  9   Producer_rating      400 non-null    float64
#  10  Critic_rating        400 non-null    float64
#  11  Trailer_views        400 non-null    int64
#  12  Time_taken           392 non-null    float64
#  13  Twitter_hastags      400 non-null    float64
#  14  Genre                400 non-null    object
# ...

# %%
uv=np.percentile(df.Marketin_expense,[99])[0]
uv
# Out:
# 472.1522199999998

# %%
df[(df.Marketin_expense>uv)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 378       26200           492.964                91.2               0.329
# 380       20800          1799.524                91.2               0.329
# 386       21000           507.876                91.2               0.300
# 398       10000           787.036                91.2               0.307
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 378  35440.900         169.7               9.240                 9.39
# 380  38707.240         165.4               9.170                 9.43
# 386  25841.860         173.5               9.145                 9.32
# 398  30291.415         173.5               9.215                 9.37
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 378            9.235            9.365           6.96         359760
# 380            9.155            9.410           6.96         417588
# ...

# %%
df.Marketin_expense[(df.Marketin_expense>3*uv)]=3*uv
# Out:
# <ipython-input-14-a7d2183313c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Marketin_expense[(df.Marketin_expense>3*uv)]=3*uv

# %%
df[(df.Marketin_expense>uv)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 378       26200         492.96400                91.2               0.329
# 380       20800        1416.45666                91.2               0.329
# 386       21000         507.87600                91.2               0.300
# 398       10000         787.03600                91.2               0.307
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 378  35440.900         169.7               9.240                 9.39
# 380  38707.240         165.4               9.170                 9.43
# 386  25841.860         173.5               9.145                 9.32
# 398  30291.415         173.5               9.215                 9.37
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 378            9.235            9.365           6.96         359760
# 380            9.155            9.410           6.96         417588
# ...

# %%
uv=np.percentile(df.Twitter_hastags,[99])[0]
uv
# Out:
# 308.0

# %%
df.Twitter_hastags[(df.Twitter_hastags>3*uv)]=3*uv
# Out:
# <ipython-input-17-50d34db13c35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Twitter_hastags[(df.Twitter_hastags>3*uv)]=3*uv

# %%
df[(df.Twitter_hastags>uv)]
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 2       69400           20.5458               69.14               0.531
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 2  39912.675         134.6               7.485                 7.57
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# 2            7.495            7.515           7.44         547051      147.88
#
#    Twitter_hastags   Genre  Avg_age_actors MPAA_film_rating  Num_multiplex  \
# 2            924.0  Comedy              38               PG            458
#
#   3D_available
# 2           NO

# %%
sns.jointplot(x='Marketin_expense',y='Collection',data=df)

# %%
sns.jointplot(x='Twitter_hastags',y='Collection',data=df)

# %%
df.describe()
# Out:
#           Collection  Marketin_expense  Production_expense  \
# count     400.000000        400.000000          400.000000
# mean    48646.500000         54.059512           73.832700
# std     18308.499136        106.576597           13.023426
# min     10000.000000         20.126400           55.920000
# 25%     37800.000000         21.321950           63.250000
# 50%     45000.000000         23.214700           69.030000
# 75%     56500.000000         34.638300           82.840000
# max    100000.000000       1416.456660          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          400.000000    400.000000    400.000000          400.000000
# mean             0.469881  35197.771537    137.581750            7.810275
# std              0.113920   4075.766926     28.990673            1.088694
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           400 non-null    int64
#  1   Marketin_expense     400 non-null    float64
#  2   Production_expense   400 non-null    float64
#  3   Multiplex_coverage   400 non-null    float64
#  4   Budget               400 non-null    float64
#  5   Movie_length         400 non-null    float64
#  6   Lead_ Actor_Rating   400 non-null    float64
#  7   Lead_Actress_rating  400 non-null    float64
#  8   Director_rating      400 non-null    float64
#  9   Producer_rating      400 non-null    float64
#  10  Critic_rating        400 non-null    float64
#  11  Trailer_views        400 non-null    int64
#  12  Time_taken           392 non-null    float64
#  13  Twitter_hastags      400 non-null    float64
#  14  Genre                400 non-null    object
# ...

# %%
df.Time_taken=df.Time_taken.fillna(df.Time_taken.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           400 non-null    int64
#  1   Marketin_expense     400 non-null    float64
#  2   Production_expense   400 non-null    float64
#  3   Multiplex_coverage   400 non-null    float64
#  4   Budget               400 non-null    float64
#  5   Movie_length         400 non-null    float64
#  6   Lead_ Actor_Rating   400 non-null    float64
#  7   Lead_Actress_rating  400 non-null    float64
#  8   Director_rating      400 non-null    float64
#  9   Producer_rating      400 non-null    float64
#  10  Critic_rating        400 non-null    float64
#  11  Trailer_views        400 non-null    int64
#  12  Time_taken           400 non-null    float64
#  13  Twitter_hastags      400 non-null    float64
#  14  Genre                400 non-null    object
# ...

# %%
for fea in df.columns:
    sns.jointplot(x=fea,y='Collection',data=df)

# %%
df['Marketin_expense']=np.log(1+df.Marketin_expense)

# %%
for fea in df.columns:
    sns.jointplot(x=fea,y='Collection',data=df)

# %%
df.describe()
# Out:
#           Collection  Marketin_expense  Production_expense  \
# count     400.000000        400.000000          400.000000
# mean    48646.500000          3.529570           73.832700
# std     18308.499136          0.741693           13.023426
# min     10000.000000          3.050523           55.920000
# 25%     37800.000000          3.105570           63.250000
# 50%     45000.000000          3.186959           69.030000
# 75%     56500.000000          3.573403           82.840000
# max    100000.000000          7.256619          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          400.000000    400.000000    400.000000          400.000000
# mean             0.469881  35197.771537    137.581750            7.810275
# std              0.113920   4075.766926     28.990673            1.088694
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %%
df['Avg_rating']=(df["Lead_ Actor_Rating"]+df["Lead_Actress_rating"]+df["Director_rating"]+df["Producer_rating"]+df["Critic_rating"])/5

# %%
df.describe()
# Out:
#           Collection  Marketin_expense  Production_expense  \
# count     400.000000        400.000000          400.000000
# mean    48646.500000          3.529570           73.832700
# std     18308.499136          0.741693           13.023426
# min     10000.000000          3.050523           55.920000
# 25%     37800.000000          3.105570           63.250000
# 50%     45000.000000          3.186959           69.030000
# 75%     56500.000000          3.573403           82.840000
# max    100000.000000          7.256619          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          400.000000    400.000000    400.000000          400.000000
# mean             0.469881  35197.771537    137.581750            7.810275
# std              0.113920   4075.766926     28.990673            1.088694
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %%
df.drop(["Lead_ Actor_Rating","Lead_Actress_rating","Director_rating","Producer_rating","Critic_rating"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000          3.050523               59.62               0.462
# 1       43200          3.070199               69.14               0.531
# 2       69400          3.070181               69.14               0.531
# 3       66800          3.074885               59.36               0.542
# 4       72400          3.108212               59.36               0.542
#
#       Budget  Movie_length  Trailer_views  Time_taken  Twitter_hastags  \
# 0  36524.125         138.7         527367      109.60          223.840
# 1  35668.655         152.4         494055      146.64          243.456
# 2  39912.675         134.6         547051      147.88          924.000
# 3  38873.890         119.3         516279      185.36          225.344
# 4  39701.585         127.7         531448      176.48          225.792
#
#       Genre  Avg_age_actors MPAA_film_rating  Num_multiplex 3D_available  \
# ...

# %%
sns.countplot(x='MPAA_film_rating',data=df)
# Out:
# <AxesSubplot:xlabel='MPAA_film_rating', ylabel='count'>

# %%
df.drop('MPAA_film_rating',axis=1,inplace=True)

# %%
df=pd.get_dummies(df)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000          3.050523               59.62               0.462
# 1       43200          3.070199               69.14               0.531
# 2       69400          3.070181               69.14               0.531
# 3       66800          3.074885               59.36               0.542
# 4       72400          3.108212               59.36               0.542
#
#       Budget  Movie_length  Trailer_views  Time_taken  Twitter_hastags  \
# 0  36524.125         138.7         527367      109.60          223.840
# 1  35668.655         152.4         494055      146.64          243.456
# 2  39912.675         134.6         547051      147.88          924.000
# 3  38873.890         119.3         516279      185.36          225.344
# 4  39701.585         127.7         531448      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Avg_rating  Genre_Action  Genre_Comedy  \
# ...

# %%
df.drop('Genre_Thriller',axis=1,inplace=True)

# %%
df.drop('3D_available_NO',axis=1,inplace=True)

# %%
df
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0         48000          3.050523               59.62               0.462
# 1         43200          3.070199               69.14               0.531
# 2         69400          3.070181               69.14               0.531
# 3         66800          3.074885               59.36               0.542
# 4         72400          3.108212               59.36               0.542
# ..          ...               ...                 ...                 ...
# 395       26200          5.274716               91.20               0.307
# 396       25000          4.930444               91.20               0.307
# 397       17000          5.161583               91.20               0.307
# 398       10000          6.669544               91.20               0.307
# 399       12600          5.390582               91.20               0.307
#
#         Budget  Movie_length  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
df.corr()
# Out:
#                     Collection  Marketin_expense  Production_expense  \
# Collection            1.000000         -0.309777           -0.373947
# Marketin_expense     -0.309777          1.000000            0.616872
# Production_expense   -0.373947          0.616872            1.000000
# Multiplex_coverage    0.303971         -0.709609           -0.747325
# Budget                0.754353         -0.308316           -0.403334
# Movie_length         -0.278718          0.534858            0.609577
# Trailer_views         0.678691         -0.528186           -0.537165
# Time_taken            0.140573          0.048022            0.024382
# Twitter_hastags       0.052651          0.049475           -0.057913
# Avg_age_actors       -0.005188          0.025260            0.028472
# Num_multiplex        -0.272365          0.638300            0.691225
# Avg_rating           -0.060482          0.533056            0.644509
# Genre_Action         -0.061967          0.034775            0.044404
# ...

# %%
plt.figure(figsize=(12,10))  # on this line I just set the size of figure to 12 by 10.
p=sns.heatmap(df.corr(), annot=True,cmap ='RdYlGn')  # seaborn has very simple solution for heatmap

# %%
df.drop('Multiplex_coverage',axis=1,inplace=True)

# %%
df
# Out:
#      Collection  Marketin_expense  Production_expense     Budget  \
# 0         48000          3.050523               59.62  36524.125
# 1         43200          3.070199               69.14  35668.655
# 2         69400          3.070181               69.14  39912.675
# 3         66800          3.074885               59.36  38873.890
# 4         72400          3.108212               59.36  39701.585
# ..          ...               ...                 ...        ...
# 395       26200          5.274716               91.20  35946.405
# 396       25000          4.930444               91.20  35579.775
# 397       17000          5.161583               91.20  31924.585
# 398       10000          6.669544               91.20  30291.415
# 399       12600          5.390582               91.20  32507.860
#
#      Movie_length  Trailer_views  Time_taken  Twitter_hastags  Avg_age_actors  \
# 0           138.7         527367      109.60          223.840              23
# ...

# %%
import statsmodels.api as sn

# %%
X=sn.add_constant(df['Budget'])

# %%
lm=sn.OLS(df['Collection'],X).fit()
lm

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Collection   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     525.5
# Date:                Wed, 23 Dec 2020   Prob (F-statistic):           9.43e-75
# Time:                        17:15:33   Log-Likelihood:                -4324.8
# No. Observations:                 400   AIC:                             8654.
# Df Residuals:                     398   BIC:                             8662.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.062e+04   5237.404    -13.485      0.000   -8.09e+04   -6.03e+04
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
y=df['Collection']

# %%
x=df[['Budget']]

# %%
lm2=LinearRegression()

# %%
lm2.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_,lm2.coef_)
# Out:
# -70624.10545910448 [3.388584]

# %%
lm2.predict(x)
# Out:
# array([53140.96012105, 50242.12816678, 64623.34643343, 61103.33620324,
#        63908.05023692, 50411.54042385, 42543.28226225, 45555.05572123,
#        35371.49671304, 42392.6935893 , 49413.89046556, 42486.81150989,
#        40227.98141565, 41357.39646277, 44124.46332822, 39192.68428913,
#        41093.86628511, 42129.16341164, 32077.36949228, 37178.56078843,
#        34223.2580818 , 41658.57380867, 44990.34819767, 38797.38902264,
#        40886.80685981, 34769.14202124, 38797.38902264, 43202.1077064 ,
#        51635.07339156, 55004.4949488 , 36915.03061077, 43672.69730937,
#        41376.22004689, 36689.14760135, 44124.46332822, 41056.21911687,
#        39324.44937796, 39493.86163503, 41677.39739279, 53517.43180342,
#        61592.74939033, 56811.55902419, 45498.58496888, 46289.17550186,
#        43616.22655701, 36331.49950309, 38289.15225143, 42882.10677638,
#        31004.42519751, 34825.6127736 , 41620.92664043, 44482.11142647,
# ...

# %%
sns.jointplot(x='Budget',y='Collection',data=df,kind='reg')

# %%
X_multi=df.drop('Collection',axis=1)

# %%
X_multi.head()
# Out:
#    Marketin_expense  Production_expense     Budget  Movie_length  \
# 0          3.050523               59.62  36524.125         138.7
# 1          3.070199               69.14  35668.655         152.4
# 2          3.070181               69.14  39912.675         134.6
# 3          3.074885               59.36  38873.890         119.3
# 4          3.108212               59.36  39701.585         127.7
#
#    Trailer_views  Time_taken  Twitter_hastags  Avg_age_actors  Num_multiplex  \
# 0         527367      109.60          223.840              23            494
# 1         494055      146.64          243.456              42            462
# 2         547051      147.88          924.000              38            458
# 3         516279      185.36          225.344              45            472
# 4         531448      176.48          225.792              55            395
#
#    Avg_rating  Genre_Action  Genre_Comedy  Genre_Drama  3D_available_YES
# ...

# %%
y_multi=df['Collection']

# %%
y_multi.head()
# Out:
# 0    48000
# 1    43200
# 2    69400
# 3    66800
# 4    72400
# Name: Collection, dtype: int64

# %%
X_multi_cons=sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const  Marketin_expense  Production_expense     Budget  Movie_length  \
# 0    1.0          3.050523               59.62  36524.125         138.7
# 1    1.0          3.070199               69.14  35668.655         152.4
# 2    1.0          3.070181               69.14  39912.675         134.6
# 3    1.0          3.074885               59.36  38873.890         119.3
# 4    1.0          3.108212               59.36  39701.585         127.7
#
#    Trailer_views  Time_taken  Twitter_hastags  Avg_age_actors  Num_multiplex  \
# 0         527367      109.60          223.840              23            494
# 1         494055      146.64          243.456              42            462
# 2         547051      147.88          924.000              38            458
# 3         516279      185.36          225.344              45            472
# 4         531448      176.48          225.792              55            395
#
# ...

# %%
lm_multi=sn.OLS(y_multi,X_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Collection   R-squared:                       0.684
# Model:                            OLS   Adj. R-squared:                  0.672
# Method:                 Least Squares   F-statistic:                     59.40
# Date:                Wed, 23 Dec 2020   Prob (F-statistic):           5.24e-87
# Time:                        17:15:36   Log-Likelihood:                -4263.0
# No. Observations:                 400   AIC:                             8556.
# Df Residuals:                     385   BIC:                             8616.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
lm3=LinearRegression()

# %%
lm3.fit(X_multi,y_multi)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_,lm3.coef_)
# Out:
# -112337.26094501576 [ 5.95563114e+01 -1.25249898e+02  2.21846663e+00 -6.86821146e+01
#   9.96053808e-02  3.37123309e+01  6.29204235e+00  4.59669519e+01
#   6.12405030e-01  5.61881860e+03 -2.72612937e+03  1.33447609e+03
#   2.03340869e+03  2.43973648e+03]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_multi,y_multi,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (320, 14)

# %%
X_test.shape
# Out:
# (80, 14)

# %%
y_train.shape
# Out:
# (320,)

# %%
y_test.shape
# Out:
# (80,)

# %%
lm_a=LinearRegression()

# %%
lm_a.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm_a.intercept_,lm_a.coef_)
# Out:
# -119374.31882687437 [-9.25773783e+02 -1.19321540e+02  2.05885284e+00 -5.39857429e+01
#   1.14664902e-01  3.76914994e+01  1.13498627e+01  9.47109047e+01
#   4.31473091e+00  5.80895937e+03 -2.89284114e+03  1.51780303e+02
#   1.88744406e+03  2.01891188e+03]

# %%
y_test_a=lm_a.predict(X_test)
y_test
# Out:
# 132    46000
# 309    40600
# 341    65400
# 196    66600
# 246    48600
#        ...
# 14     36400
# 363    33600
# 304    72200
# 361    39800
# 329    45200
# Name: Collection, Length: 80, dtype: int64

# %%
y_train_a=lm_a.predict(X_train)
y_train
# Out:
# 336    39000
# 64     66000
# 55     70800
# 106    39000
# 300    49600
#        ...
# 323    37000
# 192    72800
# 117    38400
# 47     33200
# 172    46200
# Name: Collection, Length: 320, dtype: int64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_a)
# Out:
# 0.6381589082472008

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.6872362580740938

# %%
from sklearn import preprocessing

# %%
scalar=preprocessing.StandardScaler().fit(X_train)

# %%
X_train_s=scalar.transform(X_train)
X_train_s
# Out:
# array([[-0.61437749, -0.65181069, -0.65055904, ..., -0.61588176,
#         -0.50487816, -1.20114449],
#        [-0.63206918, -1.23566757,  1.01327697, ..., -0.61588176,
#         -0.50487816,  0.8325393 ],
#        [-0.63981639, -1.26018649,  1.20862614, ..., -0.61588176,
#         -0.50487816,  0.8325393 ],
#        ...,
#        [-0.48242131,  0.08682189, -0.44577922, ..., -0.61588176,
#         -0.50487816, -1.20114449],
#        [-0.40090724, -0.38823226, -0.4336541 , ..., -0.61588176,
#         -0.50487816,  0.8325393 ],
#        [-0.49520961, -0.82650802, -1.05068802, ..., -0.61588176,
#         -0.50487816, -1.20114449]])

# %%
X_test_s=scalar.transform(X_test)
X_test_s
# Out:
# array([[-0.08023313,  1.90735199,  0.02710049, ..., -0.61588176,
#         -0.50487816,  0.8325393 ],
#        [-0.2850559 ,  0.06996513, -0.51179377, ...,  1.62368828,
#         -0.50487816,  0.8325393 ],
#        [-0.63993781, -1.21421351,  1.19784826, ...,  1.62368828,
#         -0.50487816,  0.8325393 ],
#        ...,
#        [-0.58975727, -1.11307295,  1.19111208, ..., -0.61588176,
#         -0.50487816, -1.20114449],
#        [ 1.32904953,  1.32655998, -0.13591503, ..., -0.61588176,
#         -0.50487816,  0.8325393 ],
#        [-0.57571337, -0.95063507, -0.0254417 , ...,  1.62368828,
#         -0.50487816, -1.20114449]])

# %%
from sklearn.linear_model import Ridge

# %%
lm_r=Ridge(alpha=0.5)
lm_r.fit(X_train_s, y_train)
# Out:
# Ridge(alpha=0.5)

# %%
r2_score(y_test, lm_r.predict(X_test_s))
# Out:
# 0.6383264570512293

# %%
from sklearn.model_selection import validation_curve

# %%
param_range=np.logspace(-2,8,100)
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
train_scores, test_scores = validation_curve(Ridge(), X_train_s, y_train, "alpha", param_range, scoring="r2")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass param_name=alpha, param_range=[1.00000000e-02 1.26185688e-02 1.59228279e-02 2.00923300e-02
#  2.53536449e-02 3.19926714e-02 4.03701726e-02 5.09413801e-02
#  6.42807312e-02 8.11130831e-02 1.02353102e-01 1.29154967e-01
#  1.62975083e-01 2.05651231e-01 2.59502421e-01 3.27454916e-01
#  4.13201240e-01 5.21400829e-01 6.57933225e-01 8.30217568e-01
#  1.04761575e+00 1.32194115e+00 1.66810054e+00 2.10490414e+00
#  2.65608778e+00 3.35160265e+00 4.22924287e+00 5.33669923e+00
#  6.73415066e+00 8.49753436e+00 1.07226722e+01 1.35304777e+01
#  1.70735265e+01 2.15443469e+01 2.71858824e+01 3.43046929e+01
#  4.32876128e+01 5.46227722e+01 6.89261210e+01 8.69749003e+01
#  1.09749877e+02 1.38488637e+02 1.74752840e+02 2.20513074e+02
#  2.78255940e+02 3.51119173e+02 4.43062146e+02 5.59081018e+02
#  7.05480231e+02 8.90215085e+02 1.12332403e+03 1.41747416e+03
# ...

# %%
print(train_scores)
print(test_scores)
# Out:
# [[7.20267162e-01 6.78359138e-01 6.71001414e-01 6.64157877e-01
#   7.32509997e-01]
#  [7.20267161e-01 6.78359138e-01 6.71001413e-01 6.64157876e-01
#   7.32509996e-01]
#  [7.20267160e-01 6.78359137e-01 6.71001412e-01 6.64157875e-01
#   7.32509995e-01]
#  [7.20267159e-01 6.78359136e-01 6.71001411e-01 6.64157874e-01
#   7.32509994e-01]
#  [7.20267157e-01 6.78359135e-01 6.71001410e-01 6.64157872e-01
#   7.32509991e-01]
#  [7.20267153e-01 6.78359132e-01 6.71001407e-01 6.64157869e-01
#   7.32509988e-01]
#  [7.20267148e-01 6.78359127e-01 6.71001403e-01 6.64157865e-01
#   7.32509982e-01]
#  [7.20267140e-01 6.78359121e-01 6.71001396e-01 6.64157857e-01
#   7.32509973e-01]
#  [7.20267126e-01 6.78359109e-01 6.71001385e-01 6.64157846e-01
#   7.32509958e-01]
#  [7.20267104e-01 6.78359092e-01 6.71001367e-01 6.64157827e-01
#   7.32509934e-01]
#  [7.20267070e-01 6.78359064e-01 6.71001339e-01 6.64157797e-01
#   7.32509896e-01]
#  [7.20267015e-01 6.78359019e-01 6.71001295e-01 6.64157749e-01
# ...

# %%
train_mean =np.mean(train_scores, axis=1)
train_mean
# Out:
# array([6.93259117e-01, 6.93259117e-01, 6.93259116e-01, 6.93259115e-01,
#        6.93259113e-01, 6.93259110e-01, 6.93259105e-01, 6.93259097e-01,
#        6.93259085e-01, 6.93259065e-01, 6.93259033e-01, 6.93258983e-01,
#        6.93258903e-01, 6.93258776e-01, 6.93258573e-01, 6.93258252e-01,
#        6.93257740e-01, 6.93256927e-01, 6.93255637e-01, 6.93253589e-01,
#        6.93250341e-01, 6.93245196e-01, 6.93237059e-01, 6.93224208e-01,
#        6.93203954e-01, 6.93172115e-01, 6.93122215e-01, 6.93044303e-01,
#        6.92923200e-01, 6.92735977e-01, 6.92448372e-01, 6.92009838e-01,
#        6.91346901e-01, 6.90354529e-01, 6.88885449e-01, 6.86737723e-01,
#        6.83641691e-01, 6.79248656e-01, 6.73125440e-01, 6.64760689e-01,
#        6.53589670e-01, 6.39042544e-01, 6.20615649e-01, 5.97956431e-01,
#        5.70943479e-01, 5.39739027e-01, 5.04796754e-01, 4.66822221e-01,
#        4.26699720e-01, 3.85408033e-01, 3.43944034e-01, 3.03261422e-01,
# ...

# %%
test_mean =np.mean(test_scores, axis=1)
test_mean
# Out:
# array([ 6.20598757e-01,  6.20600310e-01,  6.20602269e-01,  6.20604741e-01,
#         6.20607859e-01,  6.20611792e-01,  6.20616754e-01,  6.20623011e-01,
#         6.20630902e-01,  6.20640852e-01,  6.20653395e-01,  6.20669202e-01,
#         6.20689117e-01,  6.20714197e-01,  6.20745765e-01,  6.20785472e-01,
#         6.20835376e-01,  6.20898029e-01,  6.20976583e-01,  6.21074908e-01,
#         6.21197717e-01,  6.21350693e-01,  6.21540594e-01,  6.21775307e-01,
#         6.22063800e-01,  6.22415887e-01,  6.22841688e-01,  6.23350592e-01,
#         6.23949493e-01,  6.24639960e-01,  6.25413944e-01,  6.26247577e-01,
#         6.27092614e-01,  6.27865207e-01,  6.28432007e-01,  6.28594176e-01,
#         6.28070947e-01,  6.26485832e-01,  6.23360555e-01,  6.18123446e-01,
#         6.10139443e-01,  5.98766177e-01,  5.83434037e-01,  5.63738362e-01,
#         5.39522913e-01,  5.10931077e-01,  4.78408746e-01,  4.42658843e-01,
# ...

# %%
max(test_mean)
# Out:
# 0.6285941764937855

# %%
sns.jointplot(x=np.log(param_range),y=test_mean)

# %%
np.where(test_mean==max(test_mean))
# Out:
# (array([35], dtype=int64),)

# %%
param_range[35]
# Out:
# 34.30469286314919

# %%
lm_r_best=Ridge(alpha =param_range[31])
lm_r_best
# Out:
# Ridge(alpha=13.530477745798061)

# %%
lm_r_best.fit(X_train_s, y_train)
# Out:
# Ridge(alpha=13.530477745798061)

# %%
r2_score(y_test,lm_r_best.predict(X_test_s))
# Out:
# 0.6416254871856095

# %%
r2_score(y_train,lm_r_best.predict(X_train_s))
# Out:
# 0.6864626936256417

# %%
from sklearn.linear_model import Lasso

# %%
lm_r=Lasso(alpha=0.5)
lm_r.fit(X_train_s, y_train)
# Out:
# Lasso(alpha=0.5)

# %%
r2_score(y_test, lm_r.predict(X_test_s))
# Out:
# 0.6381778958586655

# %%
from sklearn.model_selection import validation_curve

# %%
param_range=np.logspace(-2,8,100)
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
train_scores, test_scores = validation_curve(Lasso(), X_train_s, y_train, "alpha", param_range, scoring="r2")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:67: FutureWarning: Pass param_name=alpha, param_range=[1.00000000e-02 1.26185688e-02 1.59228279e-02 2.00923300e-02
#  2.53536449e-02 3.19926714e-02 4.03701726e-02 5.09413801e-02
#  6.42807312e-02 8.11130831e-02 1.02353102e-01 1.29154967e-01
#  1.62975083e-01 2.05651231e-01 2.59502421e-01 3.27454916e-01
#  4.13201240e-01 5.21400829e-01 6.57933225e-01 8.30217568e-01
#  1.04761575e+00 1.32194115e+00 1.66810054e+00 2.10490414e+00
#  2.65608778e+00 3.35160265e+00 4.22924287e+00 5.33669923e+00
#  6.73415066e+00 8.49753436e+00 1.07226722e+01 1.35304777e+01
#  1.70735265e+01 2.15443469e+01 2.71858824e+01 3.43046929e+01
#  4.32876128e+01 5.46227722e+01 6.89261210e+01 8.69749003e+01
#  1.09749877e+02 1.38488637e+02 1.74752840e+02 2.20513074e+02
#  2.78255940e+02 3.51119173e+02 4.43062146e+02 5.59081018e+02
#  7.05480231e+02 8.90215085e+02 1.12332403e+03 1.41747416e+03
# ...

# %%
print(train_scores)
print(test_scores)
# Out:
# [[0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73251   ]
#  [0.72026716 0.67835914 0.67100141 0.66415788 0.73250999]
#  [0.72026716 0.67835913 0.67100141 0.66415787 0.73250999]
#  [0.72026716 0.67835913 0.67100141 0.66415787 0.73250999]
# ...

# %%
train_mean =np.mean(train_scores, axis=1)
train_mean
# Out:
# array([0.69325912, 0.69325912, 0.69325912, 0.69325912, 0.69325912,
#        0.69325912, 0.69325912, 0.69325912, 0.69325912, 0.69325912,
#        0.69325912, 0.69325912, 0.69325912, 0.69325912, 0.69325911,
#        0.69325911, 0.69325911, 0.6932591 , 0.69325909, 0.69325907,
#        0.69325904, 0.693259  , 0.69325892, 0.69325881, 0.69325863,
#        0.69325834, 0.69325791, 0.69325719, 0.69325605, 0.69325423,
#        0.69325134, 0.69324684, 0.69323948, 0.69322775, 0.69320901,
#        0.6931797 , 0.69313397, 0.69306195, 0.69294726, 0.69276433,
#        0.69248511, 0.6920612 , 0.69139665, 0.69045157, 0.68903298,
#        0.68695122, 0.68401667, 0.68025958, 0.67510364, 0.66803764,
#        0.65956339, 0.64839307, 0.63576557, 0.62072779, 0.60766614,
#        0.59013716, 0.56222536, 0.51778217, 0.4470166 , 0.33433614,
#        0.15893572, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
# ...

# %%
test_mean =np.mean(test_scores, axis=1)
test_mean
# Out:
# array([ 0.62059322,  0.62059333,  0.62059346,  0.62059362,  0.62059385,
#         0.62059413,  0.62059449,  0.62059495,  0.62059553,  0.62059625,
#         0.62059715,  0.62059833,  0.6205998 ,  0.62060168,  0.620604  ,
#         0.6206069 ,  0.62061062,  0.62061525,  0.6206211 ,  0.62062852,
#         0.62063782,  0.62064975,  0.62066464,  0.62068342,  0.62070731,
#         0.62073674,  0.62077314,  0.62081964,  0.62087904,  0.62095267,
#         0.62104262,  0.62115203,  0.62129464,  0.6214718 ,  0.62169078,
#         0.62191193,  0.62218233,  0.62248908,  0.62284928,  0.62325196,
#         0.62371621,  0.62428296,  0.62473977,  0.62445432,  0.62351562,
#         0.62171665,  0.61962274,  0.61858697,  0.61711267,  0.61505457,
#         0.61260731,  0.60834105,  0.60242382,  0.59512931,  0.58471039,
#         0.56821583,  0.54147274,  0.4982848 ,  0.42875781,  0.31708624,
#         0.14347998, -0.01008236, -0.01008236, -0.01008236, -0.01008236,
# ...

# %%
max(test_mean)
# Out:
# 0.6247397669995983

# %%
sns.jointplot(x=np.log(param_range),y=test_mean)

# %%
np.where(test_mean==max(test_mean))
# Out:
# (array([42], dtype=int64),)

# %%
param_range[42]
# Out:
# 174.7528400007683

# %%
lm_r_best=Lasso(alpha =param_range[42])
lm_r_best
# Out:
# Lasso(alpha=174.7528400007683)

# %%
lm_r_best.fit(X_train_s, y_train)
# Out:
# Lasso(alpha=13.530477745798061)

# %%
r2_score(y_test,lm_r_best.predict(X_test_s))
# Out:
# 0.6386654782897606

# %%
r2_score(y_train,lm_r_best.predict(X_train_s))
# Out:
# 0.6872231559971289
